# %% [markdown]
# ## Análise exploratória vinho

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Contextualização
#
# 1) Vamos ler o arquivo csv `winequality-red.csv`, construindo um Dataframe do panda. Queremos responder:
# - O que representam os dados nas colunas
# - Quantas linhas há no dataset ?
# - Quantas colunas há no dataset ?
# - Quais os tipos de dados em cada coluna ?
# - Há dados nuldos (null, missing) na base ?
#
# PAra começar, fomos falar com a área de negócio para entender o que os dados que nos passaram representam, essas são as informações que eles nos trouxeram.
#
# - Medidas de 11 variáveis físico-químicas que caracterizam cada amostra (as features do problema):
#
#   - 1 - fixed acidity - medida da acidez devido à presença de ácidos orgânicos de baixa volatilidade (ácido málico, tartarico ou cítrico) no vinho;
#   - 2 - Colatile acidity - medida da acidez devido a ácidos de baixo peso molecular (sobretudi ácido acético) presentes no vinho, que são responsáveis pelo aroma e gosto de vinagre
#   - 3 - Citric acid - medica de ácido citrico no vinho
#   - 4 - residual sugar - medida de açúcar residual presente no vinho, com origem nos resíduos de alúcar da uva que premanecem no vinho após o fim da fermentação
#   - 5 - chlorides - medida de cloretos (íons de cloro) no vinho;
#   - 6 - free sulfur dioxide - medida de dióxido de enxofre livre (isto é, que não está ligado a outras meléculas) no vinho;
#   - 7 - total sulfur dioxide - medida de dióxido de enxofre total (livre + porção ligada a outras moléculas) no vinho;
#   - 8 - density - medida da densidade do vinho
#   - 9 - pH - medida do Ph do vinho
#   - 10 - sulphates - medida de sulfatos (ions $SO_{4}^{ 2-}$)
#   - 11 - Alcohol - medida da graduação alcoólica do vinho
#   - 12 - quality - score numérico de qualidade (de 0 a 10), produzido com base em dados sensoriais
#
#   Daqui já podemos tentar formular um problema. Será que conseguimos tentar descrever a qualidade do vinho usando as demais 11 variáveis ? vamos descobrir

# %%
df = pd.read_csv('winequality-red.csv')

# %%
## Número de linhas e colunas
df.shape
# Out:
# (1599, 12)

# %%
## Tipos de dados
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
# dados nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# 2 - Vamos estudar a distribição das variáveis numéricas, calculando, para cada coluna as ptincipais estatísticas descritivas de posição (média, mediana, quartis, etc.) e de dispersão(std, IQR, etc). Se desejar, visualize as distribuições de cada variável na amostra.

# %%
df_desc = df.describe()

df_desc
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
## iqr = q3 -q1
df_desc.loc['IQR'] = df_desc.loc['75%'] - df_desc.loc['25%']

df_desc
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
# IQR         2.100000          0.250000     0.330000        0.700000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# ...

# %% [markdown]
# ### Outliers
#
# 3) Vamos verificar agora se há outliers

# %%
# visualizando distribuições comn histogramas oara ter intuição quanto a outliers
for col in df:
    sns.histplot(data=df, x=col, kde=True).set_title(f'Distribuição da Variável {col}')
    plt.show()
# Out:
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
## Método do Quartil 
for col in df.drop(columns='quality'):

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    aux_outliers = df[(df[col] < Q1-(IQR*1.5)) | (df[col] > Q3 + (IQR*1.5))]

    indices_outliers = aux_outliers.index.tolist()

    if len(indices_outliers) >= 1:
        print(f'A coluna {col} tem {len(indices_outliers)} outliers !')
        print('\nOs índices deles são:\n')
        print(indices_outliers)
    else:
        print(f'A coluna {col} não tem outliers !')
    
    print()
    print('='*80)
    print()
# Out:
# A coluna fixed acidity tem 49 outliers !
#
# Os índices deles são:
#
# [205, 206, 243, 244, 264, 294, 328, 338, 339, 347, 353, 359, 363, 364, 366, 374, 381, 391, 394, 409, 429, 440, 442, 446, 470, 472, 509, 510, 516, 538, 544, 548, 554, 555, 557, 559, 560, 564, 565, 596, 599, 601, 603, 611, 652, 680, 811, 814, 1224]
#
# ...
#
# A coluna volatile acidity tem 19 outliers !
#
# Os índices deles são:
#
# [38, 94, 120, 126, 127, 134, 199, 553, 672, 690, 700, 705, 710, 724, 899, 1261, 1299, 1312, 1467]
#
# ...
#
# A coluna citric acid tem 1 outliers !
#
# Os índices deles são:
#
# [151]
#
# ...
#
# A coluna residual sugar tem 155 outliers !
#
# Os índices deles são:
#
# ...

# %% [markdown]
# ### Estudo da variável Respota
#
# 4 - Estude os dados na coluna `quality`, que é a variável reposta do problema. Em particular, responda:
#
# - Essa é uma variável contínua ou discreta ?
# - Como as notas estão distribuidas ? quais as notas mais/menos comuns ?
# - Faze sentido discretizar esta variável em dois níveis categóricos ?
#     - Se sim, qual seria o valor de corte, e, com este corte, qual o significado de cada nível categórico ?
#     - como estes dois níveis categóricos estão distribuidos ?

# %%
df['quality'].value_counts(normalize=True) # A normalização aqui é a porcentagem
# Out:
# quality
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 4    0.033146
# 8    0.011257
# 3    0.006254
# Name: proportion, dtype: float64

# %%
display(df['quality'].describe())

sns.histplot(data=df, x = 'quality', kde=True)
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='quality', ylabel='Count'>

# %% [markdown]
# 5 - Vamos buscar a correlação das variáveis descritivas com a variável resposta para buscar algumas que pareçam influenciar mais

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(12,6))

sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# 6 - Calcule e/ou visualize (em um gráfico de barras, ou como preferir) o intervalo de confiança de 90% para a média de cada uma das variáveis físico-químicas, agrupadas pelos níveis categóricos da variável resposta quality. que conclusões são possíveis tirar destes gráficos ?

# %%
for col in df.drop(columns='quality'):

    sns.barplot(data=df, x='quality', y=col, errorbar=('ci', 90), hue='quality')
    plt.show()

# %%
df['quality_bin'] = df['quality'].apply(lambda x: 'bom' if x >5 else 'ruim')

# %%
df_bin =df.drop(columns=['quality'])
df_bin
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Salvando dataframe em um csv
df_bin.to_csv('wibequality-red-binary.csv', index=False)

# %%
df_bin
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_bin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality_bin           1599 non-null   object
# dtypes: float64(11), object(1)
# memory usage: 150.0+ KB

# %%
for col in df_bin.drop(columns='quality_bin'):
    sns.histplot(data=df_bin, x=col, kde=True, hue=df_bin['quality_bin']).set_title(f'Distribuição da variável {col}')
    plt.show()
# Out:
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Matheus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# Percebemos que há algumas variáveis que parecem ajudar a separar a qualidade do vinho com mais eficiência agora que mudamos para um problema binário.
#
# Para finalizar uma resposta da nossa pergunta devemos fazer um teste de hipótese.
