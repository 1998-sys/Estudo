# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# Out:
# c:\Users\Matheus\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Cria um dicionário em python
dados = {
    'Estado': ['Santa Cartarina', 'Rio de Janeiro', 'Tocantins', 'Bahia', 'Minas Gerais'],
    'Ano': [2004,2005,2006,2007,2008],
    'Taxa Desemprego' : [1.5,1.7,1.6,2.4,2.7]
}

# %%
for k,v in dados.items():
    print(k,v)
# Out:
# Estado ['Santa Cartarina', 'Rio de Janeiro', 'Tocantins', 'Bahia', 'Minas Gerais']
# Ano [2004, 2005, 2006, 2007, 2008]
# Taxa Desemprego [1.5, 1.7, 1.6, 2.4, 2.7]

# %%
df = pd.DataFrame(dados)

# %%
# Mostra 5 primeiras linhas 
df.head()
# Out:
#             Estado   Ano  Taxa Desemprego
# 0  Santa Cartarina  2004              1.5
# 1   Rio de Janeiro  2005              1.7
# 2        Tocantins  2006              1.6
# 3            Bahia  2007              2.4
# 4     Minas Gerais  2008              2.7

# %%
# Tipo do objeto criado
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Reorganizando as colunas
pd.DataFrame(dados, columns=['Ano', 'Estado','Taxa Desemprego'])
# Out:
#     Ano           Estado  Taxa Desemprego
# 0  2004  Santa Cartarina              1.5
# 1  2005   Rio de Janeiro              1.7
# 2  2006        Tocantins              1.6
# 3  2007            Bahia              2.4
# 4  2008     Minas Gerais              2.7

# %%
# Criando outro dataframe com os mesmos dados anteriores mas adicionando uma coluna 

df2 = pd.DataFrame(dados,
                   columns=['Estado', 'Taxa Desemprego', 'Taxa de Crescimento', 'Ano'],
                   index= ['estado1', 'estado2', 'estado3', 'estado4', 'estado5'])

# %%
df2.head()
# Out:
#                   Estado  Taxa Desemprego Taxa de Crescimento   Ano
# estado1  Santa Cartarina              1.5                 NaN  2004
# estado2   Rio de Janeiro              1.7                 NaN  2005
# estado3        Tocantins              1.6                 NaN  2006
# estado4            Bahia              2.4                 NaN  2007
# estado5     Minas Gerais              2.7                 NaN  2008

# %%
# Retorna os valores do dataframe em um arry
df2.values
# Out:
# array([['Santa Cartarina', 1.5, nan, 2004],
#        ['Rio de Janeiro', 1.7, nan, 2005],
#        ['Tocantins', 1.6, nan, 2006],
#        ['Bahia', 2.4, nan, 2007],
#        ['Minas Gerais', 2.7, nan, 2008]], dtype=object)

# %%
# Tipo dos dados
df2.dtypes
# Out:
# Estado                  object
# Taxa Desemprego        float64
# Taxa de Crescimento     object
# Ano                      int64
# dtype: object

# %%
# Retorna o título das colunas em lista
df2.columns
# Out:
# Index(['Estado', 'Taxa Desemprego', 'Taxa de Crescimento', 'Ano'], dtype='object')

# %%
# imprimindo apenas uma coluna do dataframe
df2[['Estado', 'Taxa Desemprego']]
# Out:
#                   Estado  Taxa Desemprego
# estado1  Santa Cartarina              1.5
# estado2   Rio de Janeiro              1.7
# estado3        Tocantins              1.6
# estado4            Bahia              2.4
# estado5     Minas Gerais              2.7

# %%
# Filtrando pelo índice
df2.filter(items=['estado3'], axis=0)
# Out:
#             Estado  Taxa Desemprego Taxa de Crescimento   Ano
# estado3  Tocantins              1.6                 NaN  2006

# %%
df2.head()
# Out:
#                   Estado  Taxa Desemprego Taxa de Crescimento   Ano
# estado1  Santa Cartarina              1.5                 NaN  2004
# estado2   Rio de Janeiro              1.7                 NaN  2005
# estado3        Tocantins              1.6                 NaN  2006
# estado4            Bahia              2.4                 NaN  2007
# estado5     Minas Gerais              2.7                 NaN  2008

# %% [markdown]
# ## Usando Numpy e Pandas Para Manipulação de Dados

# %%
# Importando numpy
import numpy as np

# %%
df.head()
# Out:
#             Estado   Ano  Taxa Desemprego
# 0  Santa Cartarina  2004              1.5
# 1   Rio de Janeiro  2005              1.7
# 2        Tocantins  2006              1.6
# 3            Bahia  2007              2.4
# 4     Minas Gerais  2008              2.7

# %%
# mostra o formato das variáveis
df2.dtypes
# Out:
# Estado                  object
# Taxa Desemprego        float64
# Taxa de Crescimento     object
# Ano                      int64
# dtype: object

# %%
# resumo estatístico do Dataframe
df2.describe()
# Traz as medidas estatísticas de todas as variáveis numéricas
# Out:
#        Taxa Desemprego          Ano
# count         5.000000     5.000000
# mean          1.980000  2006.000000
# std           0.535724     1.581139
# min           1.500000  2004.000000
# 25%           1.600000  2005.000000
# 50%           1.700000  2006.000000
# 75%           2.400000  2007.000000
# max           2.700000  2008.000000

# %%
# Retorna um dataframe com os valores ausentes das amostras = True
df2.isna()
# Out:
#          Estado  Taxa Desemprego  Taxa de Crescimento    Ano
# estado1   False            False                 True  False
# estado2   False            False                 True  False
# estado3   False            False                 True  False
# estado4   False            False                 True  False
# estado5   False            False                 True  False

# %%
# Verificando filtrado por coluna
df2['Taxa de Crescimento'].isna()
# Out:
# estado1    True
# estado2    True
# estado3    True
# estado4    True
# estado5    True
# Name: Taxa de Crescimento, dtype: bool

# %%
# Usando o Numpy para alimentar uma das colunas do dataframe
df2['Taxa de Crescimento'] = np.arange(5.)

# %%
df2.head()
# Out:
#                   Estado  Taxa Desemprego  Taxa de Crescimento   Ano
# estado1  Santa Cartarina              1.5                  0.0  2004
# estado2   Rio de Janeiro              1.7                  1.0  2005
# estado3        Tocantins              1.6                  2.0  2006
# estado4            Bahia              2.4                  3.0  2007
# estado5     Minas Gerais              2.7                  4.0  2008

# %%
df2.dtypes
# Out:
# Estado                  object
# Taxa Desemprego        float64
# Taxa de Crescimento    float64
# Ano                      int64
# dtype: object

# %%
df2['Taxa de Crescimento'].isna()
# Out:
# estado1    False
# estado2    False
# estado3    False
# estado4    False
# estado5    False
# Name: Taxa de Crescimento, dtype: bool

# %%
df2.describe()
# Out:
#        Taxa Desemprego  Taxa de Crescimento          Ano
# count         5.000000             5.000000     5.000000
# mean          1.980000             2.000000  2006.000000
# std           0.535724             1.581139     1.581139
# min           1.500000             0.000000  2004.000000
# 25%           1.600000             1.000000  2005.000000
# 50%           1.700000             2.000000  2006.000000
# 75%           2.400000             3.000000  2007.000000
# max           2.700000             4.000000  2008.000000

# %% [markdown]
# ## Slicing de DataFrames do Pandas

# %%
df2
# Out:
#                   Estado  Taxa Desemprego  Taxa de Crescimento   Ano
# estado1  Santa Cartarina              1.5                  0.0  2004
# estado2   Rio de Janeiro              1.7                  1.0  2005
# estado3        Tocantins              1.6                  2.0  2006
# estado4            Bahia              2.4                  3.0  2007
# estado5     Minas Gerais              2.7                  4.0  2008

# %%
# Fatiando pelas observações (index)
df2['estado2': 'estado4']
# Out:
#                  Estado  Taxa Desemprego  Taxa de Crescimento   Ano
# estado2  Rio de Janeiro              1.7                  1.0  2005
# estado3       Tocantins              1.6                  2.0  2006
# estado4           Bahia              2.4                  3.0  2007

# %%
# Fatiando o dataframe por uma condição lógica
df2[df2['Taxa Desemprego'] < 2]
# Out:
#                   Estado  Taxa Desemprego  Taxa de Crescimento   Ano
# estado1  Santa Cartarina              1.5                  0.0  2004
# estado2   Rio de Janeiro              1.7                  1.0  2005
# estado3        Tocantins              1.6                  2.0  2006

# %%
# Fatiando o dataframe pelas colunas
df2[['Estado', 'Taxa de Crescimento']]
# Out:
#                   Estado  Taxa de Crescimento
# estado1  Santa Cartarina                  0.0
# estado2   Rio de Janeiro                  1.0
# estado3        Tocantins                  2.0
# estado4            Bahia                  3.0
# estado5     Minas Gerais                  4.0

# %% [markdown]
# ## Preenchimento de valores ausentes
#
# A função fillna() é usada para preencher os valores ausentes. A função oferece muitas opções. Podemos usar um valor específico, uma função agregada (por exemplo, média()) ou valor anterior ou seguinte

# %%
dsa_df = pd.read_csv('dataset.csv')

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %%
# Soma de valores dos valores ausentes por variável
dsa_df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      2
# dtype: int64

# %%
#Extraíndo a moda da coluna Quantity
moda = dsa_df['Quantidade'].value_counts().index[0]

# %%
print(f'{moda}')
# Out:
# 3.0

# %%
# preenchendo os valores NA com a moda
dsa_df['Quantidade'].fillna(value=moda, inplace=True)

# %%
dsa_df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      0
# dtype: int64

# %% [markdown]
# ## Query (Consulta) de Dados no DataFrame do Pandas
# Com o Pandas criamos dataframes, que são essencialmente tabelas. Comotal, podemos fazer consultas, ou simplesmente queries. E para isso usamos o método query(). Veja abaixo o exemplo.

# %%
dsa_df.Valor_Venda.describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
# Gerando um novo dataframe apenas com o intervalo de vendas entre 229 e 10000
df2 = dsa_df.query('229< Valor_Venda <10000')

# %%
df2.describe()
# Out:
#        Valor_Venda   Quantidade
# count  2357.000000  2357.000000
# mean    766.679142     4.654221
# std     856.315136     2.438478
# min     229.544000     1.000000
# 25%     323.100000     3.000000
# 50%     490.320000     4.000000
# 75%     859.200000     6.000000
# max    9892.740000    14.000000

# %%
# Gerando um novo dataframe apenas com os valores de venda acima da média
df3 = df2.query('Valor_Venda > 776')

# %%
df3.head()
# Out:
#          ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 3   US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 7   CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 10  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 11  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
# 24  CA-2015-106320  2015-09-25   EB-13870  Consumer  United States   West
#
#          ID_Produto   Categoria  \
# 3   FUR-TA-10000577   Furniture
# 7   TEC-PH-10002275  Technology
# 10  FUR-TA-10001539   Furniture
# 11  TEC-PH-10002033  Technology
# 24  FUR-TA-10000577   Furniture
#
#                                      Nome_Produto  Valor_Venda  Quantidade
# 3   Bretford CR4500 Series Slim Rectangular Table     957.5775         5.0
# 7                  Mitel 5320 IP Phone VoIP phone     907.1520         6.0
# 10       Chromcraft Rectangular Conference Tables    1706.1840         9.0
# ...

# %% [markdown]
# ## Verificando a Ocorrência de Diversos Valores em uma Coluna
#
# Em nosso conjunto de dados de exemplo temos a coluna Quantidade que representa a quantidade de itens vendidos em cada uma das vendas. Imagine que precisamos saver em quais vendas foram vendidos 5,7,9 ou 11 itens
#
# Como aplicariamos esse tipo de filtro ao nosso dataframe ?
#
# Fácil: O pandas oferece o método isin() para checar diversos valores em uma coluna.

# %%
# Tamanho dataset
dsa_df.shape
# Out:
# (9994, 11)

# %%
# Então aplicamos o filtro
dsa_df[dsa_df['Quantidade'].isin([5,7,9,11])]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14    US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# ...              ...         ...        ...          ...            ...
# 9974  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9977  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9981  CA-2017-163566  2017-08-03   TB-21055     Consumer  United States
# 9982  US-2016-157728  2016-09-22   RC-19960     Consumer  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
#
#        Regiao       ID_Produto        Categoria  \
# 3       South  FUR-TA-10000577        Furniture
# ...

# %%
# Fatiando 
dsa_df[dsa_df['Quantidade'].isin([5,7,9,11])][:10]
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3   US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10  CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14  US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 21  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 22  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 27  US-2015-150630  2015-09-17   TB-21520     Consumer  United States
# 35  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
# 36  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
#
#      Regiao       ID_Produto        Categoria  \
# 3     South  FUR-TA-10000577        Furniture
# 5      West  FUR-FU-10001487        Furniture
# 9      West  OFF-AP-10002892  Office Supplies
# ...

# %% [markdown]
# ## Operadores Lógicos Para Manipulação de Dados com Pandas
#
# Os operadores lógicos são excelentes para filtrar dataframes e retornar exatamente os dados que precisamos para nosso trabalho.

# %% [markdown]
# Primeiro usaremos o operador lógico AND para checar duas condições. Serão retornados os registros quando as duas condições forem verdadeiras

# %%
# Filtrando as Vendas que ocorreram para o segmento de Home Office e na região South
dsa_df[(dsa_df.Segmento == 'Home Office') & (dsa_df.Regiao == 'South')].head()
# Out:
#           ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais Regiao  \
# 182  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 183  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 184  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 231  US-2017-100930  2017-04-07   CS-12400  Home Office  United States  South
# 232  US-2017-100930  2017-04-07   CS-12400  Home Office  United States  South
#
#           ID_Produto   Categoria  \
# 182  TEC-PH-10003273  Technology
# 183  TEC-PH-10004896  Technology
# 184  TEC-AC-10002345  Technology
# 231  FUR-TA-10001705   Furniture
# 232  FUR-TA-10003473   Furniture
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 182                                      AT&T TR1909W     503.9600         4.0
# 183                        Nokia Lumia 521 (T-Mobile)     149.9500         5.0
# ...

# %% [markdown]
# Mas pode ser necessári checar duas condições e retornar os registros se pelo menos uma for verdadeira. Nesse caso usamos o operador OR, conforme abaixo

# %%
# Filtrado as Vendas que ocorreram para o segmento de Home oofice ou Região South
dsa_df[(dsa_df.Segmento == 'Home office') | (dsa_df.Regiao == 'South')].tail()

# tail() = últimos registros
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9971  CA-2015-103772  2015-06-28   MP-17470  Home Office  United States
# 9980  US-2015-151435  2015-09-06   SW-20455     Consumer  United States
# 9987  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
# 9989  CA-2014-110422  2014-01-21   TB-21400     Consumer  United States
#
#      Regiao       ID_Produto        Categoria  \
# 9971  South  OFF-AR-10000538  Office Supplies
# 9980  South  FUR-TA-10001029        Furniture
# 9987  South  TEC-AC-10001539       Technology
# 9988  South  TEC-PH-10004006       Technology
# 9989  South  FUR-FU-10001889        Furniture
#
#                                            Nome_Produto  Valor_Venda  \
# 9971  Boston Model 1800 Electric Pencil Sharpener, Gray      140.750
# 9980                         KI Adjustable-Height Table       85.980
# ...

# %% [markdown]
# O operador de negação é o contrário do primeiro exemplo

# %%
dsa_df[(dsa_df.Segmento != 'Home Office') & (dsa_df.Regiao != 'South')].sample(5)
# Out:
#            ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 6665  CA-2016-115483  2016-07-14   JS-15880   Consumer  United States
# 8516  CA-2016-132899  2016-04-07   SF-20200   Consumer  United States
# 4521  CA-2014-109491  2014-02-20   LC-16930  Corporate  United States
# 2494  CA-2016-146206  2016-09-10   KT-16480   Consumer  United States
# 8217  CA-2014-120775  2014-10-03   RD-19930   Consumer  United States
#
#        Regiao       ID_Produto        Categoria  \
# 6665  Central  OFF-PA-10001497  Office Supplies
# 8516     East  OFF-AR-10002833  Office Supplies
# 4521  Central  FUR-FU-10000221        Furniture
# 2494  Central  TEC-PH-10000895       Technology
# 8217  Central  OFF-FA-10002676  Office Supplies
#
#                         Nome_Produto  Valor_Venda  Quantidade
# 6665                      Xerox 1914      219.840         5.0
# 8516                      Newell 322        3.640         2.0
# 4521  Master Caster Door Stop, Brown       20.320         4.0
# ...

# %% [markdown]
# ## Agrupamento de dados com Group By
#
# A função Pandas Groupby é uma função versátil e facil de usar que ajuda a obter uma visão geral dos dados. Isso torna mais fácil explorar o conjunto de dados e revelar os relacionamentos entre as variáveis
#
# O código agrupará as linhas com base nas combinações Segmento/Região/Valor_Venda e nos dará a taxa média de vendas de cada grupo

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
dsa_df.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Regiao',
#        'ID_Produto', 'Categoria', 'Nome_Produto', 'Valor_Venda', 'Quantidade'],
#       dtype='object')

# %%
dsa_df[['Segmento', 'Regiao', 'Valor_Venda']].groupby(['Segmento', 'Regiao']).mean()
# Out:
#                      Valor_Venda
# Segmento    Regiao
# Consumer    Central   207.946728
#             East      238.875539
#             South     233.390180
#             West      217.033955
# Corporate   Central   234.763466
#             East      228.516929
#             South     238.992025
#             West      235.265911
# Home Office Central   208.248046
#             East      253.911805
#             South     272.996329
#             West      239.442692

# %% [markdown]
# Na instrução acima, primeiro filtramos os dados extraindo 3 colunas: [Segmento, Regiao, Valor_Venda], na sequência, agrupamos por duas colunas: ['Segmento, Região']. E Então calculamos a média para a colua que ficou fora do GroupBy. Nesse casso a coluna Valor_Venda

# %% [markdown]
# ## Agregação Múltipla com Group By
#
# Vamos explorar mais a função groupby() pois temos diversas opções de sumarização dos dados de forma simples. No exemplo abaixo uniremos a função groupby() com a função agg() para realizar agregação multipla

# %%
# Aplicacando o Group By
dsa_df[['Segmento', 'Regiao','Valor_Venda']].groupby(['Segmento','Regiao']).agg(['mean','std','count'])
# Out:
#                     Valor_Venda
#                            mean          std count
# Segmento    Regiao
# Consumer    Central  207.946728   587.906523  1212
#             East     238.875539   633.371169  1469
#             South    233.390180   559.346824   838
#             West     217.033955   551.997547  1672
# Corporate   Central  234.763466   818.947521   673
#             East     228.516929   530.001654   877
#             South    238.992025   586.176947   510
#             West     235.265911   471.288764   960
# Home Office Central  208.248046   371.009180   438
#             East     253.911805   722.777318   502
#             South    272.996329  1404.798466   272
#             West     239.442692   529.242737   571

# %% [markdown]
# ## Filtrando Dataframe do Pandas com Base em Strings
#
# O pandas oferece diversas funções para manipulação de strings. Começaremos com os filtros de string com base nas letras iniciais e finais

# %%
dsa_df.head(1)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
#
#         ID_Produto  Categoria                       Nome_Produto  Valor_Venda  \
# 0  FUR-BO-10001798  Furniture  Bush Somerset Collection Bookcase       261.96
#
#    Quantidade
# 0         3.0

# %%
# Filtrando o dataframe pela coluna Segmento com valores que iniciam com as letras 'Con'abs
dsa_df[dsa_df.Segmento.str.startswith('Con')].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 3  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 5  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
# 5  FUR-FU-10001487        Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
# Filtrando o dataframe pela coluna Segmento com valores que terminam com as letras 'mer'abs
dsa_df[dsa_df.Segmento.str.endswith('mer')].head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520  Consumer  United States  South
# 3  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335  Consumer  United States  South
# 5  CA-2014-115812  2014-06-09   BH-11710  Consumer  United States   West
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
# 5  FUR-FU-10001487        Furniture
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %% [markdown]
# ## Split de Strings em DataFrames do Pandas
# com o pandas podemos realizar diversas tarefas de split de strings dividindo uma coluna ou extraindo elementos do nosso interesse. Vamos ao exemplo

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
dsa_df['ID_Pedido'].head()
# Out:
# 0    CA-2016-152156
# 1    CA-2016-152156
# 2    CA-2016-138688
# 3    US-2015-108966
# 4    US-2015-108966
# Name: ID_Pedido, dtype: object

# %% [markdown]
# Este é o formato dos dados da coluna 'ID_Pedido'
# - CA-2016-152156
# - CA-2016-108966
#
# Temos o país, o ano e id do pedido. Vamos dividir essa coluna e extrair o ano para gravar em uma nova coluna

# %%
#Split da coluna pelo caracter '-'
dsa_df['ID_Pedido'].str.split('-')
# Out:
# 0       [CA, 2016, 152156]
# 1       [CA, 2016, 152156]
# 2       [CA, 2016, 138688]
# 3       [US, 2015, 108966]
# 4       [US, 2015, 108966]
#                ...
# 9989    [CA, 2014, 110422]
# 9990    [CA, 2017, 121258]
# 9991    [CA, 2017, 121258]
# 9992    [CA, 2017, 121258]
# 9993    [CA, 2017, 119914]
# Name: ID_Pedido, Length: 9994, dtype: object

# %%
# Fazendo o split da coluna e extraindo o iem na posição 2 (ano)
dsa_df['Ano'] = dsa_df['ID_Pedido'].str.split('-').str[1]

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %% [markdown]
# ## Strip de Strings em DataFrames do Pandas
# O strip remove caracteres da string. Veja os exemplos

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
dsa_df['Data_Pedido'].head(3)
# Out:
# 0    2016-11-08
# 1    2016-11-08
# 2    2016-06-12
# Name: Data_Pedido, dtype: object

# %%
dsa_df.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Regiao           object
# ID_Produto       object
# Categoria        object
# Nome_Produto     object
# Valor_Venda     float64
# Quantidade      float64
# Ano              object
# dtype: object

# %% [markdown]
# A coluna 'Data_Pedido' é a data de envio do produto no formato YYYY-MM-DD. Imagine que seja necessário deixar o ano apenas com 2 dígitos sem alterar o tipo da variável. Fazemos isso com a função istrip(), ou seja, left strip

# %%
# Vamos remover os digitos 2 e 0 à esquerda do valor da variável 'Data_Pedido'
dsa_df['Data_Pedido'].str.lstrip('20')
# Out:
# 0       16-11-08
# 1       16-11-08
# 2       16-06-12
# 3       15-10-11
# 4       15-10-11
#           ...
# 9989    14-01-21
# 9990    17-02-26
# 9991    17-02-26
# 9992    17-02-26
# 9993    17-05-04
# Name: Data_Pedido, Length: 9994, dtype: object

# %% [markdown]
# Como não usamos o inplace=True a mudança e somente na memória e não altera o dataframe. Podemos usar ainda as funções rstrip() e strip() com diferentes variações de strip de strings.

# %% [markdown]
# ## Replace de Strings em DataFrames do Pandas
# Se for necessário substituir caracteres dentro de uma string o Pandas oferece uma função para isso também.
#
# por exemplo, substituir 2 caracteres em uma das colunas

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
# Susbtituímos os caracteres CG por AX na coluna 'ID_Cliente'
dsa_df['ID_Cliente'] = dsa_df['ID_Cliente'].str.replace('CG', 'AX')

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %% [markdown]
# ## Combinação de Strings em Dataframes do Pandas
# A função cat() pode ser usada para concatenar strings em um dataframe do Pandas.
#
# Vamos criar uma nova coluna concatenando as colnas 'ID_Pedido' e 'Segmento' com o separador '.'

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
dsa_df['Pedido_Segmento'] = dsa_df['ID_Pedido'].str.cat(dsa_df['Segmento'], sep = '-')

# %%
dsa_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   AX-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %% [markdown]
# ## Criação de Gráficos a Partir do Pandas
# Gráficos diretamente pelo pandas são simples, gráficos de qualidade superior matplotlib e seaborn

# %%
import sklearn
sklearn.__version__
# Out:
# '1.3.0'

# %%
# Importando o dataset iris 
from sklearn.datasets import load_iris
data = load_iris()

# %%
df = pd.DataFrame(data['data'], columns= data['feature_names'])
df['species'] = data['target']
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# Para criar um gráfico de linhas com todas as variáveis do dataframe:
df.plot()
# Out:
# <Axes: >

# %%
# Scatter - mostra a relação entre duas variáveis
df.plot.scatter(x = 'sepal length (cm)', y='sepal width (cm)')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
# gráfico de área
columns = ['sepal length (cm)', 'sepal width (cm)', 'petal width (cm)', 'sepal width (cm)']
df[columns].plot.area()
# Out:
# <Axes: >

# %%
# Calculando a média das colunas agrupadando pela coluna species e criamps um gráfico de barras com o resultado.abs
df.groupby('species').mean().plot.bar()
# Out:
# <Axes: xlabel='species'>

# %%
# Ou entrão fazemos a contagem de classes da coluna species e plotamos um gráfico de pizza
df.groupby('species').count().plot.pie(y='sepal length (cm)')
# Out:
# <Axes: ylabel='sepal length (cm)'>

# %%
# Gráfico KDE (Kernel Density Function) para cada variável do dataframe
df.plot.kde(subplots=True, figsize = (8,8))
# Out:
# array([<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>], dtype=object)

# %%
# boxplot de cada variável numérica
columns = ['sepal length (cm)', 'petal length (cm)', 'petal width (cm)', 'sepal width (cm)']
df[columns].plot.box(figsize = (8,8))
# Out:
# <Axes: >
